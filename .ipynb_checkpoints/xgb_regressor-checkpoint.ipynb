# %%
# imports 
import pandas as pd 

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from xgboost import XGBRegressor

# load data 
houses = pd.read_csv('HousePricesClean.csv')

# set up x and y and split into test and train
y = houses.price
X = houses.drop(columns = ['year_renovated', 'basement_area', 'price','id'])
X_train, X_valid, y_train, y_valid = train_test_split(X, y, random_state = 0)

# %%
my_model = XGBRegressor(n_estimators = 574, learning_rate = 0.05)
#my_model.fit(X_train, y_train, eval_set = [(X_valid, y_valid)], verbose = True)

# using cross validation 
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline
my_pipeline = Pipeline(steps = [('model', my_model)])
scores = -1 * cross_val_score(my_pipeline, X, y, cv = 5, scoring = 'neg_mean_absolute_error')
print(scores)
print(scores.mean())
# Out:
# [67329.52248098 64540.58012889 60811.25490285 64631.10251133
#  74042.26344135]
# 66270.94469307987

# %%
# manually picking best hyperparameters: 
# learning rate 0.1 n_estimators 255 , 123870
# learning rate 0.05 n_estimators 298 , 123458
# learning rate 0.05, n_estimators 574, 121647

# %%
houses.price.describe()
# Out:
# count    1.461800e+04
# mean     5.387994e+05
# std      3.672410e+05
# min      7.800000e+04
# 25%      3.200000e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
# now use grid search to find best hyperparameters for us 
# make a dictionary of hyperparamater values to search
search_space = {
    "n_estimators" : [100, 200, 500, 1000],   # the number of trees used 
    "max_depth" : [3, 6, 9],  # maximum depth of each tree 
    "gamma" : [0.01, 0.1], # minimum loss reduction required to make a further partition on a leaf node of the tree
    "learning_rate" : [0.001, 0.05, 0.01, 0.1] # how much each new tree contributes to score (helps reduce overfitting)
}

# %%
from sklearn.model_selection import GridSearchCV

xgb_model = XGBRegressor()
GS = GridSearchCV(estimator = xgb_model, 
                  param_grid = search_space, 
                  scoring = ["r2", "neg_root_mean_squared_error"], # how we compare each model?
                  refit = "r2",
                  cv = 5, 
                  verbose = 4)

# %%
GS.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-340896.597) r2: (test=0.104) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-382931.612) r2: (test=0.108) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-353080.633) r2: (test=0.105) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-329113.140) r2: (test=0.124) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-364672.059) r2: (test=0.102) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-323898.264) r2: (test=0.191) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-362766.755) r2: (test=0.200) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-334378.920) r2: (test=0.198) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-309840.710) r2: (test=0.223) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-346753.163) r2: (test=0.188) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-282228.903) r2: (test=0.386) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-313305.332) r2: (test=0.403) total time=   1.9s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-288085.384) r2: (test=0.404) total time=   0.3s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-264086.537) r2: (test=0.436) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-302805.190) r2: (test=0.381) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-236585.905) r2: (test=0.569) total time=   0.5s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-258109.595) r2: (test=0.595) total time=   0.6s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-237851.026) r2: (test=0.594) total time=   0.5s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-215764.527) r2: (test=0.623) total time=   0.5s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-254583.836) r2: (test=0.562) total time=   0.5s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-336949.075) r2: (test=0.125) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-377896.844) r2: (test=0.132) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-348092.990) r2: (test=0.130) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-324973.037) r2: (test=0.146) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-359847.797) r2: (test=0.125) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-315657.968) r2: (test=0.232) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-353062.520) r2: (test=0.242) total time=   0.3s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-325445.882) r2: (test=0.240) total time=   0.3s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-301064.750) r2: (test=0.267) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-337637.229) r2: (test=0.230) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-264065.464) r2: (test=0.463) total time=   0.7s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-293520.213) r2: (test=0.476) total time=   0.6s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-266709.281) r2: (test=0.490) total time=   0.5s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-244280.712) r2: (test=0.517) total time=   0.5s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-283307.572) r2: (test=0.458) total time=   0.5s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-210502.211) r2: (test=0.658) total time=   1.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-228628.971) r2: (test=0.682) total time=   1.4s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-202263.409) r2: (test=0.706) total time=   1.3s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-186786.010) r2: (test=0.718) total time=   1.3s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-224228.440) r2: (test=0.660) total time=   1.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-336292.298) r2: (test=0.128) total time=   0.5s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-377330.115) r2: (test=0.134) total time=   0.5s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-345887.438) r2: (test=0.141) total time=   0.4s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-323801.217) r2: (test=0.152) total time=   0.4s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-359049.208) r2: (test=0.129) total time=   0.5s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-315378.842) r2: (test=0.233) total time=   1.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-351985.094) r2: (test=0.247) total time=   1.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-321278.769) r2: (test=0.259) total time=   0.9s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-299812.390) r2: (test=0.273) total time=   0.9s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-335808.760) r2: (test=0.238) total time=   1.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-261115.390) r2: (test=0.475) total time=   2.5s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-290819.591) r2: (test=0.486) total time=   2.6s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-264690.095) r2: (test=0.497) total time=   2.4s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-240550.234) r2: (test=0.532) total time=   2.4s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-278634.678) r2: (test=0.476) total time=   2.8s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-205414.294) r2: (test=0.675) total time=   6.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-225839.841) r2: (test=0.690) total time=   5.7s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-201050.499) r2: (test=0.710) total time=   5.5s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-180824.478) r2: (test=0.735) total time=   5.4s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-216935.197) r2: (test=0.682) total time=   5.8s
# [CV 1/5] END gamma=0.01, learning_rate=0.05, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-163006.500) r2: (test=0.795) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.05, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-149834.869) r2: (test=0.863) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.05, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-139688.185) r2: (test=0.860) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.05, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-144086.763) r2: (test=0.832) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.05, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-154965.728) r2: (test=0.838) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.05, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-150466.601) r2: (test=0.826) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.05, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-133066.132) r2: (test=0.892) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.05, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-126102.115) r2: (test=0.886) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.05, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-136670.974) r2: (test=0.849) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.05, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-139309.433) r2: (test=0.869) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.05, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-143237.049) r2: (test=0.842) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.05, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-123179.009) r2: (test=0.908) total time=   0.2s
# [CV 3/5] END gamma=0.01, learning_rate=0.05, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-118038.382) r2: (test=0.900) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.05, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-129442.239) r2: (test=0.864) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.05, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-129761.358) r2: (test=0.886) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.05, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-139526.894) r2: (test=0.850) total time=   0.4s
# [CV 2/5] END gamma=0.01, learning_rate=0.05, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-120160.883) r2: (test=0.912) total time=   0.4s
# [CV 3/5] END gamma=0.01, learning_rate=0.05, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-114739.434) r2: (test=0.906) total time=   0.4s
# [CV 4/5] END gamma=0.01, learning_rate=0.05, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-125532.586) r2: (test=0.872) total time=   0.5s
# [CV 5/5] END gamma=0.01, learning_rate=0.05, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-125930.201) r2: (test=0.893) total time=   0.4s
# [CV 1/5] END gamma=0.01, learning_rate=0.05, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-152085.263) r2: (test=0.822) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.05, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-132951.124) r2: (test=0.893) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.05, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-119223.507) r2: (test=0.898) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.05, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-124307.755) r2: (test=0.875) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.05, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-144176.758) r2: (test=0.860) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.05, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-147836.931) r2: (test=0.832) total time=   0.3s
# [CV 2/5] END gamma=0.01, learning_rate=0.05, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-126829.981) r2: (test=0.902) total time=   0.2s
# [CV 3/5] END gamma=0.01, learning_rate=0.05, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-113751.675) r2: (test=0.907) total time=   0.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.05, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-120999.903) r2: (test=0.882) total time=   0.3s
# [CV 5/5] END gamma=0.01, learning_rate=0.05, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-138519.763) r2: (test=0.870) total time=   0.3s
# [CV 1/5] END gamma=0.01, learning_rate=0.05, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-147025.537) r2: (test=0.833) total time=   0.7s
# [CV 2/5] END gamma=0.01, learning_rate=0.05, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-125006.487) r2: (test=0.905) total time=   0.7s
# [CV 3/5] END gamma=0.01, learning_rate=0.05, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-112278.588) r2: (test=0.910) total time=   0.7s
# [CV 4/5] END gamma=0.01, learning_rate=0.05, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-118313.212) r2: (test=0.887) total time=   0.6s
# [CV 5/5] END gamma=0.01, learning_rate=0.05, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-136832.804) r2: (test=0.874) total time=   0.5s
# [CV 1/5] END gamma=0.01, learning_rate=0.05, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-146838.574) r2: (test=0.834) total time=   1.4s
# [CV 2/5] END gamma=0.01, learning_rate=0.05, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-125129.014) r2: (test=0.905) total time=   1.4s
# [CV 3/5] END gamma=0.01, learning_rate=0.05, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-112104.062) r2: (test=0.910) total time=   1.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.05, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-117647.810) r2: (test=0.888) total time=   1.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.05, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-137263.295) r2: (test=0.873) total time=   1.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.05, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-146397.310) r2: (test=0.835) total time=   0.4s
# [CV 2/5] END gamma=0.01, learning_rate=0.05, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-137558.845) r2: (test=0.885) total time=   0.4s
# [CV 3/5] END gamma=0.01, learning_rate=0.05, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-124149.357) r2: (test=0.889) total time=   0.4s
# [CV 4/5] END gamma=0.01, learning_rate=0.05, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-131298.542) r2: (test=0.861) total time=   0.4s
# [CV 5/5] END gamma=0.01, learning_rate=0.05, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-135972.333) r2: (test=0.875) total time=   0.4s
# [CV 1/5] END gamma=0.01, learning_rate=0.05, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-145268.768) r2: (test=0.837) total time=   0.7s
# [CV 2/5] END gamma=0.01, learning_rate=0.05, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-134944.548) r2: (test=0.889) total time=   0.7s
# [CV 3/5] END gamma=0.01, learning_rate=0.05, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-122415.083) r2: (test=0.892) total time=   0.8s
# [CV 4/5] END gamma=0.01, learning_rate=0.05, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-130094.428) r2: (test=0.863) total time=   0.7s
# [CV 5/5] END gamma=0.01, learning_rate=0.05, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-132667.746) r2: (test=0.881) total time=   0.7s
# [CV 1/5] END gamma=0.01, learning_rate=0.05, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-145026.277) r2: (test=0.838) total time=   2.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.05, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-134778.236) r2: (test=0.890) total time=   2.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.05, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-121949.869) r2: (test=0.893) total time=   2.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.05, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-129345.228) r2: (test=0.865) total time=   2.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.05, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-132445.264) r2: (test=0.881) total time=   2.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.05, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-145044.635) r2: (test=0.838) total time=   4.3s
# [CV 2/5] END gamma=0.01, learning_rate=0.05, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-134858.493) r2: (test=0.889) total time=   4.4s
# [CV 3/5] END gamma=0.01, learning_rate=0.05, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-121926.214) r2: (test=0.893) total time=   5.5s
# [CV 4/5] END gamma=0.01, learning_rate=0.05, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-129340.260) r2: (test=0.865) total time=   5.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.05, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-132420.435) r2: (test=0.882) total time=   4.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-236352.713) r2: (test=0.569) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-257835.009) r2: (test=0.596) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-237434.131) r2: (test=0.595) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-215561.659) r2: (test=0.624) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-254397.341) r2: (test=0.563) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-196753.222) r2: (test=0.702) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-200819.338) r2: (test=0.755) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-184346.745) r2: (test=0.756) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-172437.082) r2: (test=0.759) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-204561.842) r2: (test=0.717) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-163354.462) r2: (test=0.794) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-148869.379) r2: (test=0.865) total time=   0.2s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-138442.965) r2: (test=0.862) total time=   0.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-144700.494) r2: (test=0.831) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-156469.463) r2: (test=0.835) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-151242.078) r2: (test=0.824) total time=   0.4s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-131747.543) r2: (test=0.894) total time=   0.4s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-124618.461) r2: (test=0.889) total time=   0.4s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-134841.757) r2: (test=0.853) total time=   0.4s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-139646.411) r2: (test=0.868) total time=   0.4s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-210164.459) r2: (test=0.660) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-228115.660) r2: (test=0.684) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-202148.270) r2: (test=0.707) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-186418.383) r2: (test=0.719) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-224362.664) r2: (test=0.660) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-167675.025) r2: (test=0.783) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-165526.916) r2: (test=0.833) total time=   0.2s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-145946.378) r2: (test=0.847) total time=   0.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-141674.448) r2: (test=0.838) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-173249.927) r2: (test=0.797) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-153197.230) r2: (test=0.819) total time=   0.7s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-134933.174) r2: (test=0.889) total time=   0.7s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-121948.770) r2: (test=0.893) total time=   0.6s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-125751.542) r2: (test=0.872) total time=   0.7s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-144847.387) r2: (test=0.858) total time=   0.5s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-149011.911) r2: (test=0.829) total time=   1.4s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-128744.813) r2: (test=0.899) total time=   1.4s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-117202.244) r2: (test=0.901) total time=   1.3s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-122233.714) r2: (test=0.879) total time=   1.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-139489.035) r2: (test=0.869) total time=   1.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-204782.444) r2: (test=0.677) total time=   0.5s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-225616.043) r2: (test=0.690) total time=   0.6s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-200692.720) r2: (test=0.711) total time=   0.5s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-179815.029) r2: (test=0.738) total time=   0.6s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-216932.728) r2: (test=0.682) total time=   0.5s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-163851.594) r2: (test=0.793) total time=   1.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-167883.218) r2: (test=0.829) total time=   1.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-149645.010) r2: (test=0.839) total time=   1.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-143653.550) r2: (test=0.833) total time=   1.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-163576.160) r2: (test=0.819) total time=   1.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-152087.143) r2: (test=0.822) total time=   2.3s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-140921.275) r2: (test=0.879) total time=   2.3s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-126405.382) r2: (test=0.885) total time=   2.3s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-131827.155) r2: (test=0.859) total time=   2.5s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-142412.086) r2: (test=0.863) total time=   2.8s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-150702.784) r2: (test=0.825) total time=   4.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-138629.391) r2: (test=0.883) total time=   4.3s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-125277.048) r2: (test=0.887) total time=   4.4s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-130622.938) r2: (test=0.862) total time=   4.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-138552.394) r2: (test=0.870) total time=   4.3s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-154738.161) r2: (test=0.815) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-131283.585) r2: (test=0.895) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-124991.810) r2: (test=0.888) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-134505.898) r2: (test=0.854) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-139096.478) r2: (test=0.869) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-148079.295) r2: (test=0.831) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-124030.189) r2: (test=0.906) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-117845.464) r2: (test=0.900) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-127704.514) r2: (test=0.868) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-131691.284) r2: (test=0.883) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-142685.245) r2: (test=0.843) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-118908.338) r2: (test=0.914) total time=   0.2s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-111164.121) r2: (test=0.911) total time=   0.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-121373.513) r2: (test=0.881) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-127134.133) r2: (test=0.891) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-142053.965) r2: (test=0.844) total time=   0.4s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-119111.612) r2: (test=0.914) total time=   0.4s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-109340.433) r2: (test=0.914) total time=   0.4s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-119694.069) r2: (test=0.884) total time=   0.4s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-125312.294) r2: (test=0.894) total time=   0.4s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-148467.337) r2: (test=0.830) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-127479.931) r2: (test=0.901) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-114339.382) r2: (test=0.906) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-119462.054) r2: (test=0.885) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-134934.134) r2: (test=0.877) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-146664.688) r2: (test=0.834) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-126160.038) r2: (test=0.903) total time=   0.2s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-113128.898) r2: (test=0.908) total time=   0.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-117784.710) r2: (test=0.888) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-134185.876) r2: (test=0.878) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-146501.516) r2: (test=0.835) total time=   0.5s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-125842.215) r2: (test=0.904) total time=   0.5s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-112950.749) r2: (test=0.908) total time=   0.5s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-117753.421) r2: (test=0.888) total time=   0.5s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-134298.006) r2: (test=0.878) total time=   0.5s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-146719.189) r2: (test=0.834) total time=   1.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-126473.523) r2: (test=0.903) total time=   1.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-112997.067) r2: (test=0.908) total time=   1.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-117963.577) r2: (test=0.887) total time=   1.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-134574.718) r2: (test=0.878) total time=   1.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-147993.628) r2: (test=0.831) total time=   0.3s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-135265.882) r2: (test=0.889) total time=   0.3s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-124515.635) r2: (test=0.889) total time=   0.4s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-133847.612) r2: (test=0.855) total time=   0.4s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-134182.796) r2: (test=0.878) total time=   0.3s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-147652.690) r2: (test=0.832) total time=   0.8s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-135398.455) r2: (test=0.889) total time=   0.9s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-124114.057) r2: (test=0.889) total time=   1.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-133568.728) r2: (test=0.856) total time=   1.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-133719.111) r2: (test=0.879) total time=   0.8s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-147803.703) r2: (test=0.832) total time=   2.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-135516.088) r2: (test=0.888) total time=   2.2s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-124078.788) r2: (test=0.890) total time=   2.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-133592.492) r2: (test=0.856) total time=   2.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-133667.738) r2: (test=0.879) total time=   2.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-147833.971) r2: (test=0.832) total time=   4.6s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-135537.010) r2: (test=0.888) total time=   4.7s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-124085.521) r2: (test=0.890) total time=   4.8s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-133599.957) r2: (test=0.856) total time=   4.7s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-133677.123) r2: (test=0.879) total time=   4.7s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-340896.597) r2: (test=0.104) total time=   0.0s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-382931.612) r2: (test=0.108) total time=   0.0s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-353080.633) r2: (test=0.105) total time=   0.0s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-329113.140) r2: (test=0.124) total time=   0.0s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-364672.059) r2: (test=0.102) total time=   0.0s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-323898.264) r2: (test=0.191) total time=   0.0s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-362766.755) r2: (test=0.200) total time=   0.0s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-334378.920) r2: (test=0.198) total time=   0.0s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-309840.710) r2: (test=0.223) total time=   0.0s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-346753.163) r2: (test=0.188) total time=   0.0s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-282228.903) r2: (test=0.386) total time=   0.2s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-313305.332) r2: (test=0.403) total time=   0.2s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-288085.384) r2: (test=0.404) total time=   0.2s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-264086.537) r2: (test=0.436) total time=   0.2s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-302805.190) r2: (test=0.381) total time=   0.2s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-236585.905) r2: (test=0.569) total time=   0.4s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-258109.595) r2: (test=0.595) total time=   0.4s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-237851.026) r2: (test=0.594) total time=   0.4s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-215764.527) r2: (test=0.623) total time=   0.4s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-254583.836) r2: (test=0.562) total time=   0.4s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-336949.075) r2: (test=0.125) total time=   0.1s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-377896.844) r2: (test=0.132) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-348092.990) r2: (test=0.130) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-324973.037) r2: (test=0.146) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-359847.797) r2: (test=0.125) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-315657.968) r2: (test=0.232) total time=   0.2s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-353062.520) r2: (test=0.242) total time=   0.2s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-325445.882) r2: (test=0.240) total time=   0.2s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-301064.750) r2: (test=0.267) total time=   0.2s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-337637.229) r2: (test=0.230) total time=   0.2s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-264065.464) r2: (test=0.463) total time=   0.6s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-293520.213) r2: (test=0.476) total time=   0.6s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-266709.281) r2: (test=0.490) total time=   0.6s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-244280.712) r2: (test=0.517) total time=   0.6s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-283307.572) r2: (test=0.458) total time=   0.6s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-210502.211) r2: (test=0.658) total time=   1.3s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-228628.971) r2: (test=0.682) total time=   1.3s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-202263.409) r2: (test=0.706) total time=   1.2s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-186786.010) r2: (test=0.718) total time=   1.3s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-224228.440) r2: (test=0.660) total time=   1.2s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-336292.298) r2: (test=0.128) total time=   0.5s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-377330.115) r2: (test=0.134) total time=   0.5s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-345887.438) r2: (test=0.141) total time=   0.4s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-323801.217) r2: (test=0.152) total time=   0.4s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-359049.208) r2: (test=0.129) total time=   0.5s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-315378.842) r2: (test=0.233) total time=   1.1s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-351985.094) r2: (test=0.247) total time=   1.1s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-321278.769) r2: (test=0.259) total time=   0.9s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-299812.390) r2: (test=0.273) total time=   0.9s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-335808.760) r2: (test=0.238) total time=   1.0s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-261115.390) r2: (test=0.475) total time=   2.7s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-290819.591) r2: (test=0.486) total time=   2.7s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-264690.095) r2: (test=0.497) total time=   2.9s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-240550.234) r2: (test=0.532) total time=   2.5s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-278634.678) r2: (test=0.476) total time=   2.6s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-205414.294) r2: (test=0.675) total time=   5.1s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-225839.841) r2: (test=0.690) total time=   5.4s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-201050.499) r2: (test=0.710) total time=   5.6s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-180824.478) r2: (test=0.735) total time=   6.1s
# ...
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-173249.927) r2: (test=0.797) total time=   0.2s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-153197.230) r2: (test=0.819) total time=   0.6s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-134933.174) r2: (test=0.889) total time=   0.6s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-121948.770) r2: (test=0.893) total time=   0.5s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-125751.542) r2: (test=0.872) total time=   0.5s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-144847.387) r2: (test=0.858) total time=   0.5s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-149011.911) r2: (test=0.829) total time=   1.1s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-128744.813) r2: (test=0.899) total time=   1.1s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-117202.244) r2: (test=0.901) total time=   1.2s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-122233.714) r2: (test=0.879) total time=   1.2s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-139489.035) r2: (test=0.869) total time=   1.1s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-204782.444) r2: (test=0.677) total time=   0.5s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-225616.043) r2: (test=0.690) total time=   0.5s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-200692.720) r2: (test=0.711) total time=   0.5s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-179815.029) r2: (test=0.738) total time=   0.4s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-216932.728) r2: (test=0.682) total time=   0.5s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-163851.594) r2: (test=0.793) total time=   0.9s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-167883.218) r2: (test=0.829) total time=   1.0s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-149645.010) r2: (test=0.839) total time=   1.0s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-143653.550) r2: (test=0.833) total time=   1.0s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-163576.160) r2: (test=0.819) total time=   1.0s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-152087.143) r2: (test=0.822) total time=   2.2s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-140921.275) r2: (test=0.879) total time=   2.2s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-126405.382) r2: (test=0.885) total time=   2.3s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-131827.155) r2: (test=0.859) total time=   2.2s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-142412.086) r2: (test=0.863) total time=   2.3s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-150702.784) r2: (test=0.825) total time=   3.8s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-138629.391) r2: (test=0.883) total time=   4.0s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-125277.048) r2: (test=0.887) total time=   4.2s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-130622.938) r2: (test=0.862) total time=   4.1s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-138552.394) r2: (test=0.870) total time=   4.2s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-154738.161) r2: (test=0.815) total time=   0.0s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-131283.585) r2: (test=0.895) total time=   0.0s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-124991.810) r2: (test=0.888) total time=   0.0s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-134505.898) r2: (test=0.854) total time=   0.0s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-139096.478) r2: (test=0.869) total time=   0.0s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-148079.295) r2: (test=0.831) total time=   0.0s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-124030.189) r2: (test=0.906) total time=   0.0s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-117845.464) r2: (test=0.900) total time=   0.0s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-127704.514) r2: (test=0.868) total time=   0.0s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-131691.284) r2: (test=0.883) total time=   0.0s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-142685.245) r2: (test=0.843) total time=   0.2s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-118908.338) r2: (test=0.914) total time=   0.2s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-111164.121) r2: (test=0.911) total time=   0.2s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-121373.513) r2: (test=0.881) total time=   0.2s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-127134.133) r2: (test=0.891) total time=   0.2s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-142053.965) r2: (test=0.844) total time=   0.4s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-119111.612) r2: (test=0.914) total time=   0.4s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-109340.433) r2: (test=0.914) total time=   0.4s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-119694.069) r2: (test=0.884) total time=   0.4s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-125312.294) r2: (test=0.894) total time=   0.4s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-148467.337) r2: (test=0.830) total time=   0.0s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-127479.931) r2: (test=0.901) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-114339.382) r2: (test=0.906) total time=   0.0s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-119462.054) r2: (test=0.885) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-134934.134) r2: (test=0.877) total time=   0.0s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-146664.688) r2: (test=0.834) total time=   0.2s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-126160.038) r2: (test=0.903) total time=   0.2s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-113128.898) r2: (test=0.908) total time=   0.2s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-117784.710) r2: (test=0.888) total time=   0.2s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-134185.876) r2: (test=0.878) total time=   0.2s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-146501.516) r2: (test=0.835) total time=   0.5s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-125842.215) r2: (test=0.904) total time=   0.5s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-112950.749) r2: (test=0.908) total time=   0.5s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-117753.421) r2: (test=0.888) total time=   0.5s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-134298.006) r2: (test=0.878) total time=   0.5s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-146719.189) r2: (test=0.834) total time=   1.1s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-126473.523) r2: (test=0.903) total time=   1.2s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-112997.067) r2: (test=0.908) total time=   1.2s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-117963.577) r2: (test=0.887) total time=   1.1s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-134574.718) r2: (test=0.878) total time=   1.2s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-147993.628) r2: (test=0.831) total time=   0.3s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-135265.882) r2: (test=0.889) total time=   0.3s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-124515.635) r2: (test=0.889) total time=   0.4s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-133847.612) r2: (test=0.855) total time=   0.4s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-134182.796) r2: (test=0.878) total time=   0.4s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-147652.690) r2: (test=0.832) total time=   0.8s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-135398.455) r2: (test=0.889) total time=   0.8s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-124114.057) r2: (test=0.889) total time=   0.8s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-133568.728) r2: (test=0.856) total time=   0.8s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-133719.111) r2: (test=0.879) total time=   0.7s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-147803.703) r2: (test=0.832) total time=   2.2s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-135516.088) r2: (test=0.888) total time=   2.2s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-124078.788) r2: (test=0.890) total time=   2.3s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-133592.492) r2: (test=0.856) total time=   2.3s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-133667.738) r2: (test=0.879) total time=   2.2s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-147833.971) r2: (test=0.832) total time=   4.7s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-135538.137) r2: (test=0.888) total time=   4.8s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-124085.521) r2: (test=0.890) total time=   4.8s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-133599.957) r2: (test=0.856) total time=   5.2s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-133677.123) r2: (test=0.879) total time=   5.5s
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     random_state=None, ...),
#              param_grid={'gamma': [0.01, 0.1],
#                          'learning_rate': [0.001, 0.05, 0.01, 0.1],
#                          'max_depth': [3, 6, 9],
#                          'n_estimators': [100, 200, 500, 1000]},
#              refit='r2', scoring=['r2', 'neg_root_mean_squared_error'],
#              verbose=4)

# %%
print(GS.best_params_)
# Out:
# {'gamma': 0.01, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 1000}

# %%
cv_results = pd.DataFrame(GS.cv_results_)
cv_results = cv_results.sort_values(by = "rank_test_r2")
cv_results.to_csv("grid_search_results.csv")

# %% [markdown]
# # looking at the results we might pick the 3rd best model which only uses 500 trees instead of 1000 at a very
# # small sacrifice on performance
# # gamma = 0.01
# # learning rate = 0.1
# # max depth = 3
# # n_estimators = 500

# %%
# final model 
final_model = XGBRegressor(n_estimators = 500, learning_rate = 0.1, max_depth = 3, gamma = 0.01)
#my_model.fit(X_train, y_train, eval_set = [(X_valid, y_valid)], verbose = True)

# %%
# let's create a little dataframe analysing our model using different metrics!
model_evaluation = pd.DataFrame()
for metric in ['mean_absolute_error', 'median_absolute_error', 'root_mean_squared_error']:
    my_pipeline = Pipeline(steps = [('model', final_model)])
    scores = -1 * cross_val_score(my_pipeline, X, y, cv = 5, scoring = "neg_" + metric)
    model_evaluation[metric] = scores
model_evaluation["r2"] = cross_val_score(my_pipeline, X, y , cv = 5, scoring = "r2")
model_evaluation.head()
# Out:
#    mean_absolute_error  median_absolute_error  root_mean_squared_error  \
# 0         68690.174154           41089.125000            149731.916979
# 1         66435.689491           38829.015625            118035.070884
# 2         62992.139067           37852.210938            110656.686148
# 3         67475.063970           39382.156250            139864.094307
# 4         83111.239950           46062.625000            135735.603261
#
#          r2
# 0  0.846131
# 1  0.883131
# 2  0.904693
# 3  0.873714
# 4  0.852968
