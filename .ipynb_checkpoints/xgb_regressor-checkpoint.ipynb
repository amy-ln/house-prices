# %%
# imports 
import pandas as pd 

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from xgboost import XGBRegressor

# load data 
houses = pd.read_csv('HousePricesClean.csv')

# set up x and y and split into test and train
y = houses.price
X = houses.drop(columns = ['year_renovated', 'basement_area', 'price','id', 'post_code','date'])
X_train, X_valid, y_train, y_valid = train_test_split(X, y, random_state = 0)

# %%
my_model = XGBRegressor(n_estimators = 574, learning_rate = 0.05)
#my_model.fit(X_train, y_train, eval_set = [(X_valid, y_valid)], verbose = True)

# using cross validation 
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline
my_pipeline = Pipeline(steps = [('model', my_model)])
scores = -1 * cross_val_score(my_pipeline, X, y, cv = 5, scoring = 'neg_mean_absolute_error')
print(scores)
print(scores.mean())
# Out:
# [67121.6982168  64975.70275628 60717.94836643 65360.74968729
#  70108.0311324 ]
# 65656.82603184044

# %%
# manually picking best hyperparameters: 
# learning rate 0.1 n_estimators 255 , 123870
# learning rate 0.05 n_estimators 298 , 123458
# learning rate 0.05, n_estimators 574, 121647

# %%
houses.price.describe()
# Out:
# count    1.461800e+04
# mean     5.387994e+05
# std      3.672410e+05
# min      7.800000e+04
# 25%      3.200000e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
# now use grid search to find best hyperparameters for us 
# make a dictionary of hyperparamater values to search
search_space = {
    "n_estimators" : [200, 500, 1000],   # the number of trees used 
    "max_depth" : [3, 6, 9],  # maximum depth of each tree 
    "gamma" : [0.01, 0.1], # minimum loss reduction required to make a further partition on a leaf node of the tree
    "learning_rate" : [0.05, 0.01, 0.1] # how much each new tree contributes to score (helps reduce overfitting)
}

# %%
from sklearn.model_selection import GridSearchCV

xgb_model = XGBRegressor()
GS = GridSearchCV(estimator = xgb_model, 
                  param_grid = search_space, 
                  scoring = ["r2", "neg_root_mean_squared_error"], # how we compare each model?
                  refit = "r2",
                  cv = 5, 
                  verbose = 4)

# %%
GS.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# [CV 1/5] END gamma=0.01, learning_rate=0.05, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-150598.676) r2: (test=0.825) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.05, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-135607.223) r2: (test=0.888) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.05, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-127153.733) r2: (test=0.884) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.05, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-139179.107) r2: (test=0.843) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.05, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-139931.078) r2: (test=0.868) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.05, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-144126.711) r2: (test=0.840) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.05, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-122988.549) r2: (test=0.908) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.05, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-120590.508) r2: (test=0.896) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.05, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-132131.726) r2: (test=0.859) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.05, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-131206.879) r2: (test=0.884) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.05, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-139264.100) r2: (test=0.851) total time=   0.3s
# [CV 2/5] END gamma=0.01, learning_rate=0.05, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-119129.164) r2: (test=0.914) total time=   0.4s
# [CV 3/5] END gamma=0.01, learning_rate=0.05, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-119636.690) r2: (test=0.897) total time=   0.4s
# [CV 4/5] END gamma=0.01, learning_rate=0.05, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-127741.555) r2: (test=0.868) total time=   0.4s
# [CV 5/5] END gamma=0.01, learning_rate=0.05, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-127883.276) r2: (test=0.890) total time=   0.4s
# [CV 1/5] END gamma=0.01, learning_rate=0.05, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-150392.465) r2: (test=0.826) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.05, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-126521.239) r2: (test=0.903) total time=   0.2s
# [CV 3/5] END gamma=0.01, learning_rate=0.05, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-116338.498) r2: (test=0.903) total time=   0.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.05, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-122838.013) r2: (test=0.878) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.05, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-136005.603) r2: (test=0.875) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.05, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-148928.754) r2: (test=0.829) total time=   0.6s
# [CV 2/5] END gamma=0.01, learning_rate=0.05, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-125133.766) r2: (test=0.905) total time=   0.5s
# [CV 3/5] END gamma=0.01, learning_rate=0.05, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-114681.438) r2: (test=0.906) total time=   0.5s
# [CV 4/5] END gamma=0.01, learning_rate=0.05, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-121016.025) r2: (test=0.882) total time=   0.5s
# [CV 5/5] END gamma=0.01, learning_rate=0.05, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-134639.925) r2: (test=0.878) total time=   0.5s
# [CV 1/5] END gamma=0.01, learning_rate=0.05, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-148846.550) r2: (test=0.829) total time=   1.3s
# [CV 2/5] END gamma=0.01, learning_rate=0.05, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-125746.857) r2: (test=0.904) total time=   1.2s
# [CV 3/5] END gamma=0.01, learning_rate=0.05, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-114196.397) r2: (test=0.906) total time=   1.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.05, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-120545.872) r2: (test=0.882) total time=   1.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.05, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-134858.133) r2: (test=0.877) total time=   1.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.05, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-149916.376) r2: (test=0.827) total time=   0.6s
# [CV 2/5] END gamma=0.01, learning_rate=0.05, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-140480.655) r2: (test=0.880) total time=   0.6s
# [CV 3/5] END gamma=0.01, learning_rate=0.05, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-123031.805) r2: (test=0.891) total time=   0.7s
# [CV 4/5] END gamma=0.01, learning_rate=0.05, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-131304.327) r2: (test=0.861) total time=   0.7s
# [CV 5/5] END gamma=0.01, learning_rate=0.05, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-133036.267) r2: (test=0.880) total time=   0.6s
# [CV 1/5] END gamma=0.01, learning_rate=0.05, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-149821.478) r2: (test=0.827) total time=   1.9s
# [CV 2/5] END gamma=0.01, learning_rate=0.05, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-140514.566) r2: (test=0.880) total time=   2.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.05, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-122526.853) r2: (test=0.892) total time=   2.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.05, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-130845.312) r2: (test=0.861) total time=   1.9s
# [CV 5/5] END gamma=0.01, learning_rate=0.05, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-132924.986) r2: (test=0.881) total time=   1.8s
# [CV 1/5] END gamma=0.01, learning_rate=0.05, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-149888.101) r2: (test=0.827) total time=   4.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.05, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-140702.939) r2: (test=0.880) total time=  16.6s
# [CV 3/5] END gamma=0.01, learning_rate=0.05, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-122484.541) r2: (test=0.892) total time=   4.8s
# [CV 4/5] END gamma=0.01, learning_rate=0.05, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-130923.459) r2: (test=0.861) total time=   4.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.05, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-132790.315) r2: (test=0.881) total time=   4.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-196057.597) r2: (test=0.704) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-201459.520) r2: (test=0.753) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-185082.552) r2: (test=0.754) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-172972.083) r2: (test=0.758) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-203351.293) r2: (test=0.721) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-162231.484) r2: (test=0.797) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-155353.479) r2: (test=0.853) total time=   0.2s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-141320.167) r2: (test=0.857) total time=   0.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-145700.540) r2: (test=0.828) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-154710.322) r2: (test=0.838) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-150371.344) r2: (test=0.826) total time=   0.4s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-137619.857) r2: (test=0.885) total time=   0.4s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-127892.577) r2: (test=0.883) total time=   0.4s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-136400.536) r2: (test=0.849) total time=   0.4s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-138164.230) r2: (test=0.871) total time=   0.4s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-167516.773) r2: (test=0.784) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-165741.281) r2: (test=0.833) total time=   0.2s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-149291.455) r2: (test=0.840) total time=   0.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-139844.296) r2: (test=0.842) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-169656.013) r2: (test=0.806) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-151601.252) r2: (test=0.823) total time=   0.6s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-133925.203) r2: (test=0.891) total time=   0.6s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-122024.927) r2: (test=0.893) total time=   0.6s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-123776.666) r2: (test=0.876) total time=   0.6s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-139469.792) r2: (test=0.869) total time=   0.5s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-149063.404) r2: (test=0.829) total time=   1.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-127543.775) r2: (test=0.901) total time=   1.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-116692.716) r2: (test=0.902) total time=   1.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-120181.284) r2: (test=0.883) total time=   1.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-133657.205) r2: (test=0.879) total time=   1.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-163867.669) r2: (test=0.793) total time=   1.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-169512.138) r2: (test=0.825) total time=   1.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-147995.086) r2: (test=0.843) total time=   1.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-145694.200) r2: (test=0.828) total time=   1.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-163874.591) r2: (test=0.819) total time=   1.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-153435.478) r2: (test=0.819) total time=   2.4s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-140978.341) r2: (test=0.879) total time=   2.2s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-123105.260) r2: (test=0.891) total time=   2.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-133932.142) r2: (test=0.855) total time=   2.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-133565.890) r2: (test=0.879) total time=   2.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-152393.285) r2: (test=0.821) total time=   3.7s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-139239.308) r2: (test=0.882) total time=   4.4s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-121125.826) r2: (test=0.895) total time=   4.4s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-133071.250) r2: (test=0.857) total time=   4.4s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-129275.011) r2: (test=0.887) total time=   4.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-147243.595) r2: (test=0.833) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-127718.812) r2: (test=0.901) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-118490.591) r2: (test=0.899) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-133809.558) r2: (test=0.855) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-131040.145) r2: (test=0.884) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-143883.002) r2: (test=0.840) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-121204.218) r2: (test=0.911) total time=   0.2s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-115015.487) r2: (test=0.905) total time=   0.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-128990.616) r2: (test=0.865) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-125097.224) r2: (test=0.894) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-141994.746) r2: (test=0.845) total time=   0.5s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-120754.094) r2: (test=0.911) total time=   0.4s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-113885.570) r2: (test=0.907) total time=   0.4s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-127815.428) r2: (test=0.868) total time=   0.4s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-123634.649) r2: (test=0.897) total time=   0.4s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-150417.397) r2: (test=0.826) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-127749.362) r2: (test=0.901) total time=   0.2s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-121727.311) r2: (test=0.894) total time=   0.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-120436.133) r2: (test=0.883) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-133534.473) r2: (test=0.880) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-150617.421) r2: (test=0.825) total time=   0.5s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-128361.373) r2: (test=0.900) total time=   0.6s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-121140.071) r2: (test=0.895) total time=   0.6s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-120822.117) r2: (test=0.882) total time=   0.6s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-133470.540) r2: (test=0.880) total time=   0.5s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-150907.886) r2: (test=0.824) total time=   1.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-128754.400) r2: (test=0.899) total time=   1.2s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-121419.451) r2: (test=0.894) total time=   1.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-120785.807) r2: (test=0.882) total time=   1.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-133527.851) r2: (test=0.880) total time=   1.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-151085.181) r2: (test=0.824) total time=   0.7s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-137732.300) r2: (test=0.885) total time=   0.8s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-121950.658) r2: (test=0.893) total time=   0.8s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-134023.065) r2: (test=0.855) total time=   0.8s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-130680.626) r2: (test=0.885) total time=   0.7s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-151042.505) r2: (test=0.824) total time=   2.4s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-137889.228) r2: (test=0.884) total time=   2.5s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-121927.166) r2: (test=0.893) total time=   2.4s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-134042.518) r2: (test=0.855) total time=   2.4s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-130767.230) r2: (test=0.884) total time=   2.3s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-151070.700) r2: (test=0.824) total time=   4.9s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-137916.229) r2: (test=0.884) total time=   4.5s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-121941.702) r2: (test=0.893) total time=   4.5s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-134042.946) r2: (test=0.855) total time=   4.4s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-130775.393) r2: (test=0.884) total time=   4.5s
# [CV 1/5] END gamma=0.1, learning_rate=0.05, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-150598.676) r2: (test=0.825) total time=   0.0s
# [CV 2/5] END gamma=0.1, learning_rate=0.05, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-135607.223) r2: (test=0.888) total time=   0.0s
# [CV 3/5] END gamma=0.1, learning_rate=0.05, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-127153.733) r2: (test=0.884) total time=   0.0s
# [CV 4/5] END gamma=0.1, learning_rate=0.05, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-139179.107) r2: (test=0.843) total time=   0.0s
# [CV 5/5] END gamma=0.1, learning_rate=0.05, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-139931.078) r2: (test=0.868) total time=   0.0s
# [CV 1/5] END gamma=0.1, learning_rate=0.05, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-144126.711) r2: (test=0.840) total time=   0.2s
# [CV 2/5] END gamma=0.1, learning_rate=0.05, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-122988.549) r2: (test=0.908) total time=   0.2s
# [CV 3/5] END gamma=0.1, learning_rate=0.05, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-120590.508) r2: (test=0.896) total time=   0.2s
# [CV 4/5] END gamma=0.1, learning_rate=0.05, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-132131.726) r2: (test=0.859) total time=   0.2s
# [CV 5/5] END gamma=0.1, learning_rate=0.05, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-131206.879) r2: (test=0.884) total time=   0.2s
# [CV 1/5] END gamma=0.1, learning_rate=0.05, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-139264.100) r2: (test=0.851) total time=   0.4s
# [CV 2/5] END gamma=0.1, learning_rate=0.05, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-119129.164) r2: (test=0.914) total time=   0.4s
# [CV 3/5] END gamma=0.1, learning_rate=0.05, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-119636.690) r2: (test=0.897) total time=   0.4s
# [CV 4/5] END gamma=0.1, learning_rate=0.05, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-127741.555) r2: (test=0.868) total time=   0.4s
# [CV 5/5] END gamma=0.1, learning_rate=0.05, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-127883.276) r2: (test=0.890) total time=   0.4s
# [CV 1/5] END gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-150392.465) r2: (test=0.826) total time=   0.2s
# [CV 2/5] END gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-126521.239) r2: (test=0.903) total time=   0.2s
# [CV 3/5] END gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-116338.498) r2: (test=0.903) total time=   0.2s
# [CV 4/5] END gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-122838.013) r2: (test=0.878) total time=   0.2s
# [CV 5/5] END gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-136005.603) r2: (test=0.875) total time=   0.2s
# [CV 1/5] END gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-148928.754) r2: (test=0.829) total time=   0.5s
# [CV 2/5] END gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-125133.766) r2: (test=0.905) total time=   0.5s
# [CV 3/5] END gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-114681.438) r2: (test=0.906) total time=   0.5s
# [CV 4/5] END gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-121016.025) r2: (test=0.882) total time=   0.5s
# [CV 5/5] END gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-134639.925) r2: (test=0.878) total time=   0.5s
# [CV 1/5] END gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-148846.550) r2: (test=0.829) total time=   1.1s
# [CV 2/5] END gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-125746.857) r2: (test=0.904) total time=   1.3s
# [CV 3/5] END gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-114196.397) r2: (test=0.906) total time=   1.3s
# [CV 4/5] END gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-120545.872) r2: (test=0.882) total time=   1.3s
# [CV 5/5] END gamma=0.1, learning_rate=0.05, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-134858.133) r2: (test=0.877) total time=   1.4s
# [CV 1/5] END gamma=0.1, learning_rate=0.05, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-149916.376) r2: (test=0.827) total time=   0.8s
# [CV 2/5] END gamma=0.1, learning_rate=0.05, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-140480.655) r2: (test=0.880) total time=   0.8s
# [CV 3/5] END gamma=0.1, learning_rate=0.05, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-123031.805) r2: (test=0.891) total time=   1.0s
# [CV 4/5] END gamma=0.1, learning_rate=0.05, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-131304.327) r2: (test=0.861) total time=   0.9s
# [CV 5/5] END gamma=0.1, learning_rate=0.05, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-133036.267) r2: (test=0.880) total time=   0.9s
# [CV 1/5] END gamma=0.1, learning_rate=0.05, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-149821.478) r2: (test=0.827) total time=   2.3s
# [CV 2/5] END gamma=0.1, learning_rate=0.05, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-140514.566) r2: (test=0.880) total time=   2.2s
# [CV 3/5] END gamma=0.1, learning_rate=0.05, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-122526.853) r2: (test=0.892) total time=   2.2s
# [CV 4/5] END gamma=0.1, learning_rate=0.05, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-130845.312) r2: (test=0.861) total time=   1.9s
# [CV 5/5] END gamma=0.1, learning_rate=0.05, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-132924.986) r2: (test=0.881) total time=   1.9s
# [CV 1/5] END gamma=0.1, learning_rate=0.05, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-149888.101) r2: (test=0.827) total time=   4.2s
# [CV 2/5] END gamma=0.1, learning_rate=0.05, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-140702.939) r2: (test=0.880) total time=   4.6s
# [CV 3/5] END gamma=0.1, learning_rate=0.05, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-122484.541) r2: (test=0.892) total time=   4.4s
# [CV 4/5] END gamma=0.1, learning_rate=0.05, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-130923.459) r2: (test=0.861) total time=   4.5s
# [CV 5/5] END gamma=0.1, learning_rate=0.05, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-132790.315) r2: (test=0.881) total time=   4.3s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-196057.597) r2: (test=0.704) total time=   0.0s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-201459.520) r2: (test=0.753) total time=   0.0s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-185082.552) r2: (test=0.754) total time=   0.0s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-172972.083) r2: (test=0.758) total time=   0.0s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-203351.293) r2: (test=0.721) total time=   0.0s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-162231.484) r2: (test=0.797) total time=   0.2s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-155353.479) r2: (test=0.853) total time=   0.2s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-141320.167) r2: (test=0.857) total time=   0.2s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-145700.540) r2: (test=0.828) total time=   0.2s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-154710.322) r2: (test=0.838) total time=   0.2s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-150371.344) r2: (test=0.826) total time=   0.4s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-137619.857) r2: (test=0.885) total time=   0.4s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-127892.577) r2: (test=0.883) total time=   0.4s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-136400.536) r2: (test=0.849) total time=   0.4s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-138164.230) r2: (test=0.871) total time=   0.4s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-167516.773) r2: (test=0.784) total time=   0.2s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-165741.281) r2: (test=0.833) total time=   0.2s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-149291.455) r2: (test=0.840) total time=   0.2s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-139844.296) r2: (test=0.842) total time=   0.2s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-169656.013) r2: (test=0.806) total time=   0.2s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-151601.252) r2: (test=0.823) total time=   0.5s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-133925.203) r2: (test=0.891) total time=   0.5s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-122024.927) r2: (test=0.893) total time=   0.6s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-123776.666) r2: (test=0.876) total time=   0.6s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-139469.792) r2: (test=0.869) total time=   0.5s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-149063.404) r2: (test=0.829) total time=   1.1s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-127543.775) r2: (test=0.901) total time=   1.1s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-116692.716) r2: (test=0.902) total time=   1.1s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-120181.284) r2: (test=0.883) total time=   1.1s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-133657.205) r2: (test=0.879) total time=   1.1s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-163867.669) r2: (test=0.793) total time=   1.0s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-169512.138) r2: (test=0.825) total time=   1.0s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-147995.086) r2: (test=0.843) total time=   1.0s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-145694.200) r2: (test=0.828) total time=   1.0s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-163874.591) r2: (test=0.819) total time=   1.0s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-153435.478) r2: (test=0.819) total time=   2.2s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-140978.341) r2: (test=0.879) total time=   2.2s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-123105.260) r2: (test=0.891) total time=   2.7s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-133932.142) r2: (test=0.855) total time=   2.1s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-133565.890) r2: (test=0.879) total time=   2.2s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-152393.285) r2: (test=0.821) total time=   3.6s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-139239.308) r2: (test=0.882) total time=   3.9s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-121125.826) r2: (test=0.895) total time=   4.1s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-133071.250) r2: (test=0.857) total time=   4.1s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-129275.011) r2: (test=0.887) total time=   3.5s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-147243.595) r2: (test=0.833) total time=   0.0s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-127718.812) r2: (test=0.901) total time=   0.0s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-118490.591) r2: (test=0.899) total time=   0.0s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-133809.558) r2: (test=0.855) total time=   0.0s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-131040.145) r2: (test=0.884) total time=   0.0s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-143883.002) r2: (test=0.840) total time=   0.2s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-121204.218) r2: (test=0.911) total time=   0.2s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-115015.487) r2: (test=0.905) total time=   0.2s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-128990.616) r2: (test=0.865) total time=   0.2s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-125097.224) r2: (test=0.894) total time=   0.2s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-141994.746) r2: (test=0.845) total time=   0.4s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-120754.094) r2: (test=0.911) total time=   0.4s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-113885.570) r2: (test=0.907) total time=   0.4s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-127815.428) r2: (test=0.868) total time=   0.4s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-123634.649) r2: (test=0.897) total time=   0.4s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-150417.397) r2: (test=0.826) total time=   0.2s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-127749.362) r2: (test=0.901) total time=   0.2s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-121727.311) r2: (test=0.894) total time=   0.2s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-120436.133) r2: (test=0.883) total time=   0.2s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-133534.473) r2: (test=0.880) total time=   0.2s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-150617.421) r2: (test=0.825) total time=   0.5s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-128361.373) r2: (test=0.900) total time=   0.5s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-121140.071) r2: (test=0.895) total time=   0.5s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-120822.117) r2: (test=0.882) total time=   0.5s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-133470.540) r2: (test=0.880) total time=   0.5s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-150907.886) r2: (test=0.824) total time=   1.1s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-128754.400) r2: (test=0.899) total time=   1.1s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-121419.451) r2: (test=0.894) total time=   1.2s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-120785.807) r2: (test=0.882) total time=   1.2s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-133527.851) r2: (test=0.880) total time=   1.2s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-151085.181) r2: (test=0.824) total time=   0.8s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-137732.300) r2: (test=0.885) total time=   0.8s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-121950.658) r2: (test=0.893) total time=   0.8s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-134023.065) r2: (test=0.855) total time=   0.8s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-130680.626) r2: (test=0.885) total time=   0.7s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-151042.505) r2: (test=0.824) total time=   2.1s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-137889.228) r2: (test=0.884) total time=   2.1s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-121927.166) r2: (test=0.893) total time=   2.1s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-134042.518) r2: (test=0.855) total time=   2.1s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-130767.230) r2: (test=0.884) total time=   2.0s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-151070.700) r2: (test=0.824) total time=   4.3s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-137916.229) r2: (test=0.884) total time=   4.5s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-121941.702) r2: (test=0.893) total time=   4.8s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-134043.140) r2: (test=0.855) total time=   4.5s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-130772.867) r2: (test=0.884) total time=   4.5s
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     random_state=None, ...),
#              param_grid={'gamma': [0.01, 0.1],
#                          'learning_rate': [0.05, 0.01, 0.1],
#                          'max_depth': [3, 6, 9],
#                          'n_estimators': [200, 500, 1000]},
#              refit='r2', scoring=['r2', 'neg_root_mean_squared_error'],
#              verbose=4)

# %%
print(GS.best_params_)
# Out:
# {'gamma': 0.01, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 1000}

# %%
cv_results = pd.DataFrame(GS.cv_results_)
cv_results = cv_results.sort_values(by = "rank_test_r2")
cv_results.to_csv("grid_search_results.csv")

# %%
# final model 
final_model = XGBRegressor(n_estimators = 1000, learning_rate = 0.1, max_depth = 3, gamma = 0.01)
#my_model.fit(X_train, y_train, eval_set = [(X_valid, y_valid)], verbose = True)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline

# let's create a little dataframe analysing our model using different metrics!
model_evaluation = pd.DataFrame()
for metric in ['mean_absolute_error', 'median_absolute_error', 'root_mean_squared_error']:
    my_pipeline = Pipeline(steps = [('model', final_model)])
    scores = -1 * cross_val_score(my_pipeline, X, y, cv = 5, scoring = "neg_" + metric)
    model_evaluation[metric] = scores
model_evaluation["r2"] = cross_val_score(my_pipeline, X, y , cv = 5, scoring = "r2")
model_evaluation.head()
# Out:
#    mean_absolute_error  median_absolute_error  root_mean_squared_error  \
# 0         69459.261743           39443.828125            150648.257125
# 1         66292.215282           39742.437500            116983.945845
# 2         63546.557635           37254.765625            110748.680924
# 3         66761.018135           39713.171875            139108.232069
# 4         83049.796247           45120.406250            136935.245083
#
#          r2
# 0  0.844242
# 1  0.885203
# 2  0.904534
# 3  0.875076
# 4  0.850357

# %%
from pickle import dump
final_model.fit(X_train, y_train)
with open("final_model.pkl", "wb") as f:
    dump(final_model, f, protocol = 5)
